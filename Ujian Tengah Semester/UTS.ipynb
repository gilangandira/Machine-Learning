# %%
import pandas as pd
import numpy as np
import sklearn
import matplotlib.pyplot as plt

# %%
dataA = [
        ["Kopiko",52], 
        ["Torabika",39],
        ["Beng Beng",78],
        ['Choki Choki',13],
        ['Teh Pucuk',78],
        ['Energen',29]
        ]

# form dataframe from data
df = pd.DataFrame(dataA, columns=["Produk", "Stok"])
#b = df.iloc[2]
print(df)
# Out:
#         Produk  Stok
# 0       Kopiko    52
# 1     Torabika    39
# 2    Beng Beng    78
# 3  Choki Choki    13
# 4    Teh Pucuk    78
# 5      Energen    29

# %%
df.plot(x="Produk", y="Stok",
        kind="line", )
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
df.groupby(['Produk']).sum().plot(kind='pie' ,y='Stok',autopct='%1.0f%%')
# Out:
# <AxesSubplot: ylabel='Stok'>
